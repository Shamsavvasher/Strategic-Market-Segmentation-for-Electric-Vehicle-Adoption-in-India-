# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
from sklearn.preprocessing import OneHotEncoder

# %%
dataset = pd.read_csv('/content/sample_data/Project 2_Feynn_labs_Dataset.csv')

# %%
df=pd.DataFrame(dataset)

# %%
df.head()
# Out:
#                                Name Manufacturer    Location  Year  \
# 0            Maruti Wagon R LXI CNG       Maruti      Mumbai  2010
# 1  Hyundai Creta 1.6 CRDi SX Option      Hyundai        Pune  2015
# 2                      Honda Jazz V        Honda     Chennai  2011
# 3                 Maruti Ertiga VDI       Maruti     Chennai  2012
# 4   Audi A4 New 2.0 TDI Multitronic         Audi  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Engine   Power  Seats  \
# 0              72000       CNG       Manual      First     998   58.16      5
# 1              41000    Diesel       Manual      First    1582  126.20      5
# 2              46000    Petrol       Manual      First    1199   88.70      5
# 3              87000    Diesel       Manual      First    1248   88.76      7
# 4              40670    Diesel    Automatic     Second    1968  140.80      5
#
#    Mileage  Price
# 0    26.60   1.75
# 1    19.67  12.50
# 2    18.20   4.50
# 3    20.77   6.00
# 4    15.20  17.74

# %%
df.tail()
# Out:
#                           Name Manufacturer   Location  Year  \
# 5970          Maruti Swift VDI       Maruti      Delhi  2014
# 5971  Hyundai Xcent 1.1 CRDi S      Hyundai     Jaipur  2015
# 5972     Mahindra Xylo D4 BSIV     Mahindra     Jaipur  2012
# 5973        Maruti Wagon R VXI       Maruti    Kolkata  2013
# 5974     Chevrolet Beat Diesel    Chevrolet  Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Engine  Power  \
# 5970              27365    Diesel       Manual      First    1248   74.0
# 5971             100000    Diesel       Manual      First    1120   71.0
# 5972              55000    Diesel       Manual     Second    2498  112.0
# 5973              46000    Petrol       Manual      First     998   67.1
# 5974              47000    Diesel       Manual      First     936   57.6
#
#       Seats  Mileage  Price
# 5970      5    28.40   4.75
# 5971      5    24.40   4.00
# 5972      8    14.00   2.90
# 5973      5    18.90   2.65
# 5974      5    25.44   2.50

# %%
df['Location']
# Out:
# 0           Mumbai
# 1             Pune
# 2          Chennai
# 3          Chennai
# 4       Coimbatore
#            ...
# 5970         Delhi
# 5971        Jaipur
# 5972        Jaipur
# 5973       Kolkata
# 5974     Hyderabad
# Name: Location, Length: 5975, dtype: object

# %%
df['Location'].isnull().sum()
# Out:
# np.int64(0)

# %%
print ("Rows     : " , cars.shape[0])
print ("Columns  : " , cars.shape[1])
print ("#"*40,"\n","Features : \n\n", cars.columns.tolist())
print ("#"*40,"\nMissing values :\n\n", cars.isnull().sum().sort_values(ascending=False))
print( "#"*40,"\nPercent of missing :\n\n", round(cars.isna().sum() / cars.isna().count() * 100, 2))
print ("#"*40,"\nUnique values :  \n\n", cars.nunique())
# Out:
# Rows     :  5975
# Columns  :  13
# ########################################
#  Features :
#
#  ['Name', 'Manufacturer', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Engine CC', 'Power', 'Seats', 'Mileage Km/L', 'Price']
# ########################################
# Missing values :
#
#  Name                 0
# Manufacturer         0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Engine CC            0
# Power                0
# Seats                0
# Mileage Km/L         0
# Price                0
# dtype: int64
# ########################################
# Percent of missing :
#
#  Name                 0.0
# Manufacturer         0.0
# Location             0.0
# Year                 0.0
# Kilometers_Driven    0.0
# Fuel_Type            0.0
# Transmission         0.0
# Owner_Type           0.0
# Engine CC            0.0
# Power                0.0
# Seats                0.0
# Mileage Km/L         0.0
# Price                0.0
# dtype: float64
# ########################################
# Unique values :
#
#  Name                 1855
# Manufacturer           31
# Location               11
# Year                   22
# Kilometers_Driven    3080
# Fuel_Type               4
# Transmission            2
# Owner_Type              4
# Engine CC             145
# Power                 368
# Seats                   9
# Mileage Km/L          430
# Price                1369
# dtype: int64

# %%
df['Location'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
df['Name'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Name'].value_counts()
# Out:
# Name
# Mahindra XUV500 W8 2WD                        49
# Maruti Swift VDI                              45
# Maruti Swift Dzire VDI                        34
# Honda City 1.5 S MT                           34
# Maruti Swift VDI BSIV                         31
#                                               ..
# Mercedes-Benz GLA Class 200 Sport              1
# Skoda Rapid Ultima 1.6 TDI Elegance            1
# Mercedes-Benz New C-Class C 200 AVANTGARDE     1
# Toyota Corolla Altis 1.8 G CVT                 1
# Skoda Laura L and K AT                         1
# Name: count, Length: 1855, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Name', 'Manufacturer', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Engine', 'Power', 'Seats',
#        'Mileage', 'Price'],
#       dtype='object')

# %%
cat_col = [
    "Fuel_Type",
    "Location",
    "Transmission",
    "Seats",
    "Year",
    "Owner_Type",

]
for column in cat_col:
    print(cars[column].value_counts())
    print("#" * 40)
# Out:
# Fuel_Type
# Diesel    3195
# Petrol    2714
# CNG         56
# LPG         10
# Name: count, dtype: int64
# ########################################
# Location
# Mumbai        784
# Hyderabad     741
# Kochi         648
# Coimbatore    634
# Pune          613
# Delhi         549
# Kolkata       530
# Chennai       490
# Jaipur        410
# Bangalore     353
# Ahmedabad     223
# Name: count, dtype: int64
# ########################################
# Transmission
# Manual       4266
# Automatic    1709
# Name: count, dtype: int64
# ########################################
# Seats
# 5     5012
# 7      674
# 8      134
# 4       99
# 6       31
# 2       16
# 10       5
# 9        3
# 0        1
# Name: count, dtype: int64
# ########################################
# Year
# 2014    795
# 2015    741
# 2016    740
# 2013    648
# 2017    586
# 2012    572
# 2011    461
# 2010    339
# 2018    298
# 2009    196
# 2008    169
# 2007    123
# 2019    102
# 2006     75
# 2005     55
# 2004     29
# 2003     15
# 2002     14
# 2001      7
# 2000      4
# 1998      4
# 1999      2
# Name: count, dtype: int64
# ########################################
# Owner_Type
# First     4903
# Second     953
# Third      111
# Fourth       8
# Name: count, dtype: int64
# ########################################

# %%
df.describe()
# Out:
#               Year  Kilometers_Driven       Engine        Power        Seats  \
# count  5975.000000       5.975000e+03  5975.000000  5975.000000  5975.000000
# mean   2013.386778       5.867431e+04  1621.606695   112.599819     5.278828
# std       3.247238       9.155851e+04   601.036987    53.659495     0.808959
# min    1998.000000       1.710000e+02   624.000000    34.200000     0.000000
# 25%    2012.000000       3.390800e+04  1198.000000    74.000000     5.000000
# 50%    2014.000000       5.300000e+04  1493.000000    92.700000     5.000000
# 75%    2016.000000       7.300000e+04  1984.000000   138.100000     5.000000
# max    2019.000000       6.500000e+06  5998.000000   560.000000    10.000000
#
#            Mileage        Price
# count  5975.000000  5975.000000
# mean     18.179408     9.501647
# std       4.521801    11.205736
# min       0.000000     0.440000
# 25%      15.200000     3.500000
# 50%      18.160000     5.650000
# 75%      21.100000     9.950000
# max      33.540000   160.000000

# %%
typeoffuel=['CNG','LPG']
df.loc[cars.Fuel_Type.isin(typeoffuel)].head(10)
# Out:
#                                         Name Manufacturer   Location  Year  \
# 0                     Maruti Wagon R LXI CNG       Maruti     Mumbai  2010
# 5            Hyundai EON LPG Era Plus Option      Hyundai  Hyderabad  2012
# 127                   Maruti Wagon R LXI CNG       Maruti       Pune  2013
# 325        Maruti Zen Estilo LXI Green (CNG)       Maruti       Pune  2008
# 437   Maruti Eeco 5 STR With AC Plus HTR CNG       Maruti      Kochi  2017
# 834              Maruti Alto Green LXi (CNG)       Maruti      Delhi  2012
# 888             Hyundai Accent Executive CNG      Hyundai  Hyderabad  2010
# 931              Maruti Wagon R LXI LPG BSIV       Maruti  Hyderabad  2012
# 982             Maruti Wagon R LXI DUO BSIII       Maruti     Mumbai  2008
# 1130       Maruti Zen Estilo LXI Green (CNG)       Maruti  Ahmedabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Engine  Power  \
# 0                 72000       CNG       Manual      First     998  58.16
# 5                 75000       LPG       Manual      First     814  55.20
# 127               89900       CNG       Manual      First     998  58.16
# 325               42496       CNG       Manual      First     998  67.10
# 437               31841       CNG       Manual      First    1196  73.00
# 834               65537       CNG       Manual      First     796  38.40
# 888               95637       CNG       Manual     Second    1495  93.70
# 931               72000       LPG       Manual      First     998  58.20
# 982               64226       LPG       Manual      First    1061  57.50
# 1130              76000       CNG       Manual      First     998  67.10
#
#       Seats  Mileage  Price
# 0         5    26.60   1.75
# 5         5    21.10   2.35
# 127       5    26.60   3.25
# 325       5    26.30   1.40
# 437       5    15.10   4.70
# 834       5    26.83   2.10
# 888       5    13.20   1.90
# 931       5    26.20   2.85
# 982       5    17.30   1.45
# 1130      5    26.30   2.00

# %%
print(cars.columns)
# Out:
# Index(['Name', 'Manufacturer', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Engine CC', 'Power',
#        'Seats', 'Mileage Km/L', 'Price'],
#       dtype='object')

# %%
df[['Engine','Power','Mileage']].sample(10)
# Out:
#       Engine   Power  Mileage
# 3228    1591  121.30    17.01
# 4633    2967  241.38    16.77
# 3525    1186   73.97    24.00
# 5065    1197   85.80    18.50
# 2892    1197   81.86    18.90
# 637     1995  190.00    18.12
# 1210    1198   73.90    16.47
# 1412    2143  136.00    17.90
# 2844     814   55.20    21.10
# 1909    1197   85.80    19.10

# %%
plt.style.use('ggplot')
numeric_columns = cars.select_dtypes(include=np.number).columns.tolist()
plt.figure(figsize=(20,25))

for i, variable in enumerate(numeric_columns):
                     plt.subplot(10,3,i+1)

                     sns.distplot(cars[variable],kde=False,color='blue')
                     plt.tight_layout()
                     plt.title(variable)
# Out:
# /tmp/ipython-input-57-379152758.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars[variable],kde=False,color='blue')

# %%
cat_columns=['Location','Fuel_Type','Transmission', 'Owner_Type']
plt.figure(figsize=(15,21))
for i, variable in enumerate(cat_columns):
                     plt.subplot(4,2,i+1)
                     order = cars[variable].value_counts(ascending=False).index
                     ax=sns.countplot(x=cars[variable], data=cars , order=order ,palette='viridis')
                     for p in ax.patches:
                           percentage = '{:.1f}%'.format(100 * p.get_height()/len(cars[variable]))
                           x = p.get_x() + p.get_width() / 2 - 0.05
                           y = p.get_y() + p.get_height()
                           plt.annotate(percentage, (x, y),ha='center')
                     plt.xticks(rotation=90)
                     plt.tight_layout()
                     plt.title(variable)
# Out:
# /tmp/ipython-input-59-2778814208.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=cars[variable], data=cars , order=order ,palette='viridis')
# /tmp/ipython-input-59-2778814208.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=cars[variable], data=cars , order=order ,palette='viridis')
# /tmp/ipython-input-59-2778814208.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=cars[variable], data=cars , order=order ,palette='viridis')
# /tmp/ipython-input-59-2778814208.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=cars[variable], data=cars , order=order ,palette='viridis')

# %%
numeric_columns= numeric_columns = cars.select_dtypes(include=np.number).columns.tolist()
plt.figure(figsize=(13,17))

for i, variable in enumerate(numeric_columns):
                     plt.subplot(5,2,i+1)
                     sns.scatterplot(x=cars[variable],y=cars['Price']).set(title='Price vs '+ variable)
                     #plt.xticks(rotation=90)
                     plt.tight_layout()

# %%
numeric_df = cars.select_dtypes(include=['number'])
corr_matrix = numeric_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='YlGnBu', fmt=".2f", square=True)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.title("Price vs Power based on Transmission")
sns.scatterplot(y='Power', x='Price', hue='Transmission', data=cars)
# Out:
# <Axes: title={'center': 'Price vs Power based on Transmission'}, xlabel='Price', ylabel='Power'>

# %%
plt.figure(figsize=(10,7))
plt.title("Price Vs Mileage")
sns.scatterplot(y='Price', x='Mileage Km/L', hue='Fuel_Type', data=cars)
# Out:
# <Axes: title={'center': 'Price Vs Mileage'}, xlabel='Mileage Km/L', ylabel='Price'>
